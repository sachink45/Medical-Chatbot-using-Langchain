# %%
import os
os.chdir("Medical-Chatbot-using-Langchain")

# %%
# %pwd
# Out:
# 'f:\\medical_chatbot\\Medical-Chatbot-using-Langchain'

# %%
# Out:
# Error loading file data\Medical_book.pdf
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File f:\medical_chatbot\Medical-Chatbot-using-Langchain\myenv\Lib\site-packages\langchain_community\document_loaders\parsers\pdf.py:359, in PyPDFParser.lazy_parse(self, blob)
#     358 try:
# --> 359     import pypdf
#     360 except ImportError:
#
# ModuleNotFoundError: No module named 'pypdf'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 5
#       3     doc = loader.load()
#       4     return doc
# ----> 5 extract_text = text_split("data")
#
# Cell In[21], line 3, in text_split(path)
#       1 def text_split(path):
#       2     loader = DirectoryLoader(path, glob = "*.pdf", loader_cls = PyPDFLoader)
# ----> 3     doc = loader.load()
#       4     return doc
#
# ...
